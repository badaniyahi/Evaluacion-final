# %% [markdown]
# # Requerimientos

# %% [markdown]
# ## PyScopus

# %%
# !pip install pyscopus==1.0.3a2
# Out:
# Collecting pyscopus==1.0.3a2
#   Downloading pyscopus-1.0.3a2-py3-none-any.whl.metadata (2.5 kB)
# Downloading pyscopus-1.0.3a2-py3-none-any.whl (11 kB)
# Installing collected packages: pyscopus
# Successfully installed pyscopus-1.0.3a2

# %% [markdown]
# Librerías

# %%
from pyscopus import Scopus
import numpy
import pandas
import requests

# %% [markdown]
# ### Enlace del Colab con Scopus (API KEY)
#
# *   El usuario debe disponer de una clave **personal**
# *   Más información en https://dev.elsevier.com/

# %%
key = "f0de53a9dc5d65593bcee05b775a6e8b"
scopus = Scopus(key)

# %% [markdown]
# ## Búsqueda:
#
# Ejemplo:
#
# TITLE-ABS-KEY((("oxytocin") AND ("cheminformatics") AND ("docking")) OR ("oxytocin" AND "dog" AND "docking")  OR ("oxytocin" AND "virtual" AND "simulations"))

# %% [markdown]
# Busqueda 1:
#
# TITLE-ABS-KEY((("columns") AND ("flooding") AND ("operational") AND (trays)) OR (("towers") AND ("flooding") AND ("operational") AND (trays)))

# %%
s = input("Ingresa tus palabras de búsqueda: ")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# Ingresa tus palabras de búsqueda: TITLE-ABS-KEY((("columns") AND ("flooding") AND ("operational") AND (trays)) OR (("towers") AND ("flooding") AND ("operational") AND (trays)))

# %%
from IPython.display import display
display(search_df)
# Out:
#       scopus_id                                              title  \
# 0   85166968086  Unsupervised anomaly detection model for diese...
# 1   85127937514           Condensate Stabilizer Flooding Diagnosis
# 2   85107688112  A thermal-hydrodynamic model to evaluate the p...
# 3   85041403345  Rate-based hydrodynamics and reaction performa...
# 4   85040810834  Performance evaluation of a rectifier column u...
# 5   84941271478  Mechanical design and hydrodynamic analysis of...
# 6   84948702349  Reducing fouling in ethylene primary fractiona...
# 7   84906822427  Effects of packing parameters on hydrodynamic ...
# 8   84930255037  Particle swarm optimization technique for the ...
# 9   84880698260     Experimental hydrodynamic study of valve trays
# 10  77957813896  Distillation troubleshooting by Gamma scanning...
# 11  49449086915                                Small but efficient
# 12  30844444130  Effect of increasing the load in the Amuay Ref...
# 13   1942496497  Designing sieve-tray columns. Part 2: column d...
# 14  85004262852          Hydraulic Performances of Turbogrid Trays
# 15  84944908463             Hydraulic Performances of Ripple Trays
#
#                                      publication_name      issn  \
# 0                 Computer Aided Chemical Engineering  15707946
# 1   Society of Petroleum Engineers - SPE Conferenc...      None
# 2   Chemical Engineering and Processing - Process ...  02552701
# 3                 Computer Aided Chemical Engineering  15707946
# 4                                          Nukleonika  00295922
# 5   Chemical Engineering and Processing: Process I...  02552701
# 6     AIChE Ethylene Producers Conference Proceedings      None
# 7            Xiandai Huagong/Modern Chemical Industry  02534320
# 8   Applications of Metaheuristics in Process Engi...      None
# 9                        Chemical Engineering Science  00092509
# 10           Xiandai Huagong/Modern Chemical Industry  02534320
# 11                                  Chemical Engineer  03020797
# 12  Revista Tecnica de la Facultad de Ingenieria U...  02540770
# 13                               Chemical Engineering      None
# 14                            KAGAKU KOGAKU RONBUNSHU  0386216X
# 15                            KAGAKU KOGAKU RONBUNSHU  0386216X
#
#                                                  isbn     eissn  \
# 0                                                None      None
# 1          [{'@_fa': 'true', '$': '[9781613997062]'}]      None
# 2                                                None      None
# 3                                                None      None
# 4                                                None  15085791
# 5                                                None      None
# 6          [{'@_fa': 'true', '$': '[9781510806924]'}]      None
# 7                                                None      None
# 8   [{'@_fa': 'true', '$': '[9783319065083, 331906...      None
# 9                                                None      None
# 10                                               None      None
# 11                                               None      None
# 12                                               None      None
# 13                                               None      None
# 14                                               None  13499203
# 15                                               None  13499203
#
#            volume page_range  cover_date                                 doi  \
# 0              52  1873-1878  2023-01-01  10.1016/B978-0-443-15274-0.50297-3
# 1            None       None  2022-01-01                   10.2118/200058-MS
# 2             166       None  2021-09-01           10.1016/j.cep.2021.108482
# 3              40    103-108  2017-10-01  10.1016/B978-0-444-63965-3.50019-2
# 4              62    285-287  2017-01-01              10.1515/nuka-2017-0041
# 5              97      55-65  2015-11-01           10.1016/j.cep.2015.09.002
# 6    2015-January    301-312  2015-01-01                                None
# 7              34    140-144  2014-08-20                                None
# 8   9783319065083    153-182  2014-04-01         10.1007/978-3-319-06508-3_6
# 9             100      23-32  2013-01-01           10.1016/j.ces.2013.03.030
# 10             30        4-7  2010-05-01                                None
# 11           None      42-43  2008-08-01                                None
# 12             19    189-198  1996-12-01                                None
# 13             96       None  1989-01-01                                None
# 14              3    569-574  1977-01-01         10.1252/kakoronbunshu.3.569
# 15              2    589-594  1976-01-01         10.1252/kakoronbunshu.2.589
#
#     citation_count                                        affiliation  \
# 0                0  [{'name': 'SOCAR Turkey', 'city': 'Istanbul', ...
# 1                0   [{'name': 'PDO', 'city': None, 'country': None}]
# 2                8  [{'name': 'Universidad Autónoma de Querétaro',...
# 3                0  [{'name': 'Universidad de Guanajuato', 'city':...
# 4                3  [{'name': 'Philippine Nuclear Research Institu...
# 5               17  [{'name': 'Universidad Tecnológica del Suroest...
# 6                0                                               None
# 7                1  [{'name': 'Zhejiang University of Technology',...
# 8                6  [{'name': 'Scientific Design Co.', 'city': 'Li...
# 9               21  [{'name': 'IFP Energies nouvelles', 'city': 'R...
# 10               0  [{'name': 'Bayer Technology and Engineering (S...
# 11               0  [{'name': 'Nederlandse Organisatie voor toegep...
# 12               0  [{'name': 'Grupo de Ingeniería de Procesos', '...
# 13               9                                               None
# 14               2  [{'name': 'Okayama University', 'city': 'Okaya...
# 15               3  [{'name': 'Okayama University', 'city': 'Okaya...
#
#          aggregation_type subtype_description authors  \
# 0             Book Series        Book Chapter      []
# 1   Conference Proceeding    Conference Paper      []
# 2                 Journal             Article      []
# 3             Book Series        Book Chapter      []
# 4                 Journal             Article      []
# 5                 Journal             Article      []
# 6   Conference Proceeding    Conference Paper      []
# 7                 Journal             Article      []
# 8                    Book        Book Chapter      []
# 9                 Journal             Article      []
# 10                Journal             Article      []
# 11          Trade Journal             Article      []
# 12                Journal             Article      []
# 13                Journal             Article      []
# 14                Journal             Article      []
# 15                Journal             Article      []
#
#                                             full_text
# 0   https://api.elsevier.com/content/article/eid/1...
# 1                                                None
# 2   https://api.elsevier.com/content/article/eid/1...
# 3   https://api.elsevier.com/content/article/eid/1...
# 4                                                None
# 5   https://api.elsevier.com/content/article/eid/1...
# 6                                                None
# 7                                                None
# 8                                                None
# 9   https://api.elsevier.com/content/article/eid/1...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None

# %%
search_df.shape
# Out:
# (16, 16)

# %%
search_df.to_csv('search_df.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from IPython.display import display
display(search_df)
# Out:
#       scopus_id                                              title  \
# 0   85166968086  Unsupervised anomaly detection model for diese...
# 1   85127937514           Condensate Stabilizer Flooding Diagnosis
# 2   85107688112  A thermal-hydrodynamic model to evaluate the p...
# 3   85041403345  Rate-based hydrodynamics and reaction performa...
# 4   85040810834  Performance evaluation of a rectifier column u...
# 5   84941271478  Mechanical design and hydrodynamic analysis of...
# 6   84948702349  Reducing fouling in ethylene primary fractiona...
# 7   84906822427  Effects of packing parameters on hydrodynamic ...
# 8   84930255037  Particle swarm optimization technique for the ...
# 9   84880698260     Experimental hydrodynamic study of valve trays
# 10  77957813896  Distillation troubleshooting by Gamma scanning...
# 11  49449086915                                Small but efficient
# 12  30844444130  Effect of increasing the load in the Amuay Ref...
# 13   1942496497  Designing sieve-tray columns. Part 2: column d...
# 14  85004262852          Hydraulic Performances of Turbogrid Trays
# 15  84944908463             Hydraulic Performances of Ripple Trays
#
#                                      publication_name      issn  \
# 0                 Computer Aided Chemical Engineering  15707946
# 1   Society of Petroleum Engineers - SPE Conferenc...      None
# 2   Chemical Engineering and Processing - Process ...  02552701
# 3                 Computer Aided Chemical Engineering  15707946
# 4                                          Nukleonika  00295922
# 5   Chemical Engineering and Processing: Process I...  02552701
# 6     AIChE Ethylene Producers Conference Proceedings      None
# 7            Xiandai Huagong/Modern Chemical Industry  02534320
# 8   Applications of Metaheuristics in Process Engi...      None
# 9                        Chemical Engineering Science  00092509
# 10           Xiandai Huagong/Modern Chemical Industry  02534320
# 11                                  Chemical Engineer  03020797
# 12  Revista Tecnica de la Facultad de Ingenieria U...  02540770
# 13                               Chemical Engineering      None
# 14                            KAGAKU KOGAKU RONBUNSHU  0386216X
# 15                            KAGAKU KOGAKU RONBUNSHU  0386216X
#
#                                                  isbn     eissn  \
# 0                                                None      None
# 1          [{'@_fa': 'true', '$': '[9781613997062]'}]      None
# 2                                                None      None
# 3                                                None      None
# 4                                                None  15085791
# 5                                                None      None
# 6          [{'@_fa': 'true', '$': '[9781510806924]'}]      None
# 7                                                None      None
# 8   [{'@_fa': 'true', '$': '[9783319065083, 331906...      None
# 9                                                None      None
# 10                                               None      None
# 11                                               None      None
# 12                                               None      None
# 13                                               None      None
# 14                                               None  13499203
# 15                                               None  13499203
#
#            volume page_range  cover_date                                 doi  \
# 0              52  1873-1878  2023-01-01  10.1016/B978-0-443-15274-0.50297-3
# 1            None       None  2022-01-01                   10.2118/200058-MS
# 2             166       None  2021-09-01           10.1016/j.cep.2021.108482
# 3              40    103-108  2017-10-01  10.1016/B978-0-444-63965-3.50019-2
# 4              62    285-287  2017-01-01              10.1515/nuka-2017-0041
# 5              97      55-65  2015-11-01           10.1016/j.cep.2015.09.002
# 6    2015-January    301-312  2015-01-01                                None
# 7              34    140-144  2014-08-20                                None
# 8   9783319065083    153-182  2014-04-01         10.1007/978-3-319-06508-3_6
# 9             100      23-32  2013-01-01           10.1016/j.ces.2013.03.030
# 10             30        4-7  2010-05-01                                None
# 11           None      42-43  2008-08-01                                None
# 12             19    189-198  1996-12-01                                None
# 13             96       None  1989-01-01                                None
# 14              3    569-574  1977-01-01         10.1252/kakoronbunshu.3.569
# 15              2    589-594  1976-01-01         10.1252/kakoronbunshu.2.589
#
#     citation_count                                        affiliation  \
# 0                0  [{'name': 'SOCAR Turkey', 'city': 'Istanbul', ...
# 1                0   [{'name': 'PDO', 'city': None, 'country': None}]
# 2                8  [{'name': 'Universidad Autónoma de Querétaro',...
# 3                0  [{'name': 'Universidad de Guanajuato', 'city':...
# 4                3  [{'name': 'Philippine Nuclear Research Institu...
# 5               17  [{'name': 'Universidad Tecnológica del Suroest...
# 6                0                                               None
# 7                1  [{'name': 'Zhejiang University of Technology',...
# 8                6  [{'name': 'Scientific Design Co.', 'city': 'Li...
# 9               21  [{'name': 'IFP Energies nouvelles', 'city': 'R...
# 10               0  [{'name': 'Bayer Technology and Engineering (S...
# 11               0  [{'name': 'Nederlandse Organisatie voor toegep...
# 12               0  [{'name': 'Grupo de Ingeniería de Procesos', '...
# 13               9                                               None
# 14               2  [{'name': 'Okayama University', 'city': 'Okaya...
# 15               3  [{'name': 'Okayama University', 'city': 'Okaya...
#
#          aggregation_type subtype_description authors  \
# 0             Book Series        Book Chapter      []
# 1   Conference Proceeding    Conference Paper      []
# 2                 Journal             Article      []
# 3             Book Series        Book Chapter      []
# 4                 Journal             Article      []
# 5                 Journal             Article      []
# 6   Conference Proceeding    Conference Paper      []
# 7                 Journal             Article      []
# 8                    Book        Book Chapter      []
# 9                 Journal             Article      []
# 10                Journal             Article      []
# 11          Trade Journal             Article      []
# 12                Journal             Article      []
# 13                Journal             Article      []
# 14                Journal             Article      []
# 15                Journal             Article      []
#
#                                             full_text
# 0   https://api.elsevier.com/content/article/eid/1...
# 1                                                None
# 2   https://api.elsevier.com/content/article/eid/1...
# 3   https://api.elsevier.com/content/article/eid/1...
# 4                                                None
# 5   https://api.elsevier.com/content/article/eid/1...
# 6                                                None
# 7                                                None
# 8                                                None
# 9   https://api.elsevier.com/content/article/eid/1...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None

# %%
from IPython.display import display
display(search_df)
# Out:
#       scopus_id                                              title  \
# 0   85166968086  Unsupervised anomaly detection model for diese...
# 1   85127937514           Condensate Stabilizer Flooding Diagnosis
# 2   85107688112  A thermal-hydrodynamic model to evaluate the p...
# 3   85041403345  Rate-based hydrodynamics and reaction performa...
# 4   85040810834  Performance evaluation of a rectifier column u...
# 5   84941271478  Mechanical design and hydrodynamic analysis of...
# 6   84948702349  Reducing fouling in ethylene primary fractiona...
# 7   84906822427  Effects of packing parameters on hydrodynamic ...
# 8   84930255037  Particle swarm optimization technique for the ...
# 9   84880698260     Experimental hydrodynamic study of valve trays
# 10  77957813896  Distillation troubleshooting by Gamma scanning...
# 11  49449086915                                Small but efficient
# 12  30844444130  Effect of increasing the load in the Amuay Ref...
# 13   1942496497  Designing sieve-tray columns. Part 2: column d...
# 14  85004262852          Hydraulic Performances of Turbogrid Trays
# 15  84944908463             Hydraulic Performances of Ripple Trays
#
#                                      publication_name      issn  \
# 0                 Computer Aided Chemical Engineering  15707946
# 1   Society of Petroleum Engineers - SPE Conferenc...      None
# 2   Chemical Engineering and Processing - Process ...  02552701
# 3                 Computer Aided Chemical Engineering  15707946
# 4                                          Nukleonika  00295922
# 5   Chemical Engineering and Processing: Process I...  02552701
# 6     AIChE Ethylene Producers Conference Proceedings      None
# 7            Xiandai Huagong/Modern Chemical Industry  02534320
# 8   Applications of Metaheuristics in Process Engi...      None
# 9                        Chemical Engineering Science  00092509
# 10           Xiandai Huagong/Modern Chemical Industry  02534320
# 11                                  Chemical Engineer  03020797
# 12  Revista Tecnica de la Facultad de Ingenieria U...  02540770
# 13                               Chemical Engineering      None
# 14                            KAGAKU KOGAKU RONBUNSHU  0386216X
# 15                            KAGAKU KOGAKU RONBUNSHU  0386216X
#
#                                                  isbn     eissn  \
# 0                                                None      None
# 1          [{'@_fa': 'true', '$': '[9781613997062]'}]      None
# 2                                                None      None
# 3                                                None      None
# 4                                                None  15085791
# 5                                                None      None
# 6          [{'@_fa': 'true', '$': '[9781510806924]'}]      None
# 7                                                None      None
# 8   [{'@_fa': 'true', '$': '[9783319065083, 331906...      None
# 9                                                None      None
# 10                                               None      None
# 11                                               None      None
# 12                                               None      None
# 13                                               None      None
# 14                                               None  13499203
# 15                                               None  13499203
#
#            volume page_range  cover_date                                 doi  \
# 0              52  1873-1878  2023-01-01  10.1016/B978-0-443-15274-0.50297-3
# 1            None       None  2022-01-01                   10.2118/200058-MS
# 2             166       None  2021-09-01           10.1016/j.cep.2021.108482
# 3              40    103-108  2017-10-01  10.1016/B978-0-444-63965-3.50019-2
# 4              62    285-287  2017-01-01              10.1515/nuka-2017-0041
# 5              97      55-65  2015-11-01           10.1016/j.cep.2015.09.002
# 6    2015-January    301-312  2015-01-01                                None
# 7              34    140-144  2014-08-20                                None
# 8   9783319065083    153-182  2014-04-01         10.1007/978-3-319-06508-3_6
# 9             100      23-32  2013-01-01           10.1016/j.ces.2013.03.030
# 10             30        4-7  2010-05-01                                None
# 11           None      42-43  2008-08-01                                None
# 12             19    189-198  1996-12-01                                None
# 13             96       None  1989-01-01                                None
# 14              3    569-574  1977-01-01         10.1252/kakoronbunshu.3.569
# 15              2    589-594  1976-01-01         10.1252/kakoronbunshu.2.589
#
#     citation_count                                        affiliation  \
# 0                0  [{'name': 'SOCAR Turkey', 'city': 'Istanbul', ...
# 1                0   [{'name': 'PDO', 'city': None, 'country': None}]
# 2                8  [{'name': 'Universidad Autónoma de Querétaro',...
# 3                0  [{'name': 'Universidad de Guanajuato', 'city':...
# 4                3  [{'name': 'Philippine Nuclear Research Institu...
# 5               17  [{'name': 'Universidad Tecnológica del Suroest...
# 6                0                                               None
# 7                1  [{'name': 'Zhejiang University of Technology',...
# 8                6  [{'name': 'Scientific Design Co.', 'city': 'Li...
# 9               21  [{'name': 'IFP Energies nouvelles', 'city': 'R...
# 10               0  [{'name': 'Bayer Technology and Engineering (S...
# 11               0  [{'name': 'Nederlandse Organisatie voor toegep...
# 12               0  [{'name': 'Grupo de Ingeniería de Procesos', '...
# 13               9                                               None
# 14               2  [{'name': 'Okayama University', 'city': 'Okaya...
# 15               3  [{'name': 'Okayama University', 'city': 'Okaya...
#
#          aggregation_type subtype_description authors  \
# 0             Book Series        Book Chapter      []
# 1   Conference Proceeding    Conference Paper      []
# 2                 Journal             Article      []
# 3             Book Series        Book Chapter      []
# 4                 Journal             Article      []
# 5                 Journal             Article      []
# 6   Conference Proceeding    Conference Paper      []
# 7                 Journal             Article      []
# 8                    Book        Book Chapter      []
# 9                 Journal             Article      []
# 10                Journal             Article      []
# 11          Trade Journal             Article      []
# 12                Journal             Article      []
# 13                Journal             Article      []
# 14                Journal             Article      []
# 15                Journal             Article      []
#
#                                             full_text
# 0   https://api.elsevier.com/content/article/eid/1...
# 1                                                None
# 2   https://api.elsevier.com/content/article/eid/1...
# 3   https://api.elsevier.com/content/article/eid/1...
# 4                                                None
# 5   https://api.elsevier.com/content/article/eid/1...
# 6                                                None
# 7                                                None
# 8                                                None
# 9   https://api.elsevier.com/content/article/eid/1...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None

# %%
search_df.shape
# Out:
# (16, 16)

# %% [markdown]
# ## Artículos, conference papers, books, etc

# %%
search_df.subtype_description.unique()
# Out:
# array(['Book Chapter', 'Conference Paper', 'Article'], dtype=object)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada tipo de publicación y ordenar los datos por el índice
subtype_description = search_df['subtype_description'].value_counts()

# Crear el gráfico de barras con coloración por tipo de publicación
ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# Agregar etiquetas y título
plt.ylabel('Cantidad')
plt.title('Tipo de publicación')

# Formatear el eje y con un decimal
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.0f'))

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-16-c525a455e4cc>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=subtype_description.index, y=subtype_description.values, palette='viridis')

# %%
import pandas as pd

# Dividir la columna "cover_date" y crear la columna "year"
search_df['year'] = search_df['cover_date'].apply(lambda x: x.split('-')[0])

# %%
search_df.head(3)
# Out:
#      scopus_id                                              title  \
# 0  85166968086  Unsupervised anomaly detection model for diese...
# 1  85127937514           Condensate Stabilizer Flooding Diagnosis
# 2  85107688112  A thermal-hydrodynamic model to evaluate the p...
#
#                                     publication_name      issn  \
# 0                Computer Aided Chemical Engineering  15707946
# 1  Society of Petroleum Engineers - SPE Conferenc...      None
# 2  Chemical Engineering and Processing - Process ...  02552701
#
#                                          isbn eissn volume page_range  \
# 0                                        None  None     52  1873-1878
# 1  [{'@_fa': 'true', '$': '[9781613997062]'}]  None   None       None
# 2                                        None  None    166       None
#
#    cover_date                                 doi  citation_count  \
# 0  2023-01-01  10.1016/B978-0-443-15274-0.50297-3               0
# 1  2022-01-01                   10.2118/200058-MS               0
# 2  2021-09-01           10.1016/j.cep.2021.108482               8
#
#                                          affiliation       aggregation_type  \
# 0  [{'name': 'SOCAR Turkey', 'city': 'Istanbul', ...            Book Series
# 1   [{'name': 'PDO', 'city': None, 'country': None}]  Conference Proceeding
# 2  [{'name': 'Universidad Autónoma de Querétaro',...                Journal
#
#   subtype_description authors  \
# 0        Book Chapter      []
# 1    Conference Paper      []
# 2             Article      []
#
#                                            full_text  year
# 0  https://api.elsevier.com/content/article/eid/1...  2023
# 1                                               None  2022
# 2  https://api.elsevier.com/content/article/eid/1...  2021

# %% [markdown]
# ## Frecuencia de publicaciones por año

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Contar las ocurrencias de cada año y ordenar los datos por el índice
year_counts = search_df['year'].value_counts().sort_index()

# Crear el gráfico de barras con coloración por año
ax = sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# Agregar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Número de publicaciones')
plt.title('Publicaciones por año')
plt.xticks(rotation=45)

# Establecer los valores del eje y
ax.set_yticks([1, 2, 3, 4])

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-19-ea52143cf8a9>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=year_counts.index, y=year_counts.values, palette='viridis')

# %%
search_df.citation_count.unique()
# Out:
# array([ 0,  8,  3, 17,  1,  6, 21,  9,  2])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
df = pd.DataFrame(search_df) #.sort_index(ascending=False)

# Crear el gráfico de dispersión con coloración por recurrencia
sns.scatterplot(data=df, x='publication_name', y='year', hue='citation_count', palette='viridis')

# Agregar etiquetas y título
plt.xlabel('Revistas')
plt.ylabel('Año')
plt.title('Revistas y año de publicación')
plt.xticks(rotation=90)

# Cambiar el título de la leyenda
plt.legend(title='Citaciones')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Análisis descriptivo

# %%
print("Cantidad de Filas y columnas:", search_df.shape)
# Out:
# Cantidad de Filas y columnas: (16, 17)

# %%
print('Nombre columnas:',search_df.columns)
# Out:
# Nombre columnas: Index(['scopus_id', 'title', 'publication_name', 'issn', 'isbn', 'eissn',
#        'volume', 'page_range', 'cover_date', 'doi', 'citation_count',
#        'affiliation', 'aggregation_type', 'subtype_description', 'authors',
#        'full_text', 'year'],
#       dtype='object')

# %%
search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scopus_id            16 non-null     object
#  1   title                16 non-null     object
#  2   publication_name     16 non-null     object
#  3   issn                 12 non-null     object
#  4   isbn                 3 non-null      object
#  5   eissn                3 non-null      object
#  6   volume               14 non-null     object
#  7   page_range           13 non-null     object
#  8   cover_date           16 non-null     object
#  9   doi                  10 non-null     object
#  10  citation_count       16 non-null     int64
#  11  affiliation          14 non-null     object
#  12  aggregation_type     16 non-null     object
#  13  subtype_description  16 non-null     object
#  14  authors              16 non-null     object
#  15  full_text            5 non-null      object
#  16  year                 16 non-null     object
# dtypes: int64(1), object(16)
# memory usage: 2.2+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame de ejemplo
df = pd.DataFrame(search_df)

# Crear el gráfico de barras
plt.bar(df['publication_name'], df['citation_count'])

# Agregar etiquetas y título
plt.xlabel('publication_name')
plt.ylabel('citation_count')
plt.title('citation_count por publication_name')
plt.xticks(rotation=90)

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga del dataframe

# %%
df = pd.DataFrame(search_df)

# %% [markdown]
# # Visualizar el DataFrame

# %%
print("DataFrame Original:search_df")
print(df)
# Out:
# DataFrame Original:search_df
#       scopus_id                                              title  \
# 0   85166968086  Unsupervised anomaly detection model for diese...
# 1   85127937514           Condensate Stabilizer Flooding Diagnosis
# 2   85107688112  A thermal-hydrodynamic model to evaluate the p...
# 3   85041403345  Rate-based hydrodynamics and reaction performa...
# 4   85040810834  Performance evaluation of a rectifier column u...
# 5   84941271478  Mechanical design and hydrodynamic analysis of...
# 6   84948702349  Reducing fouling in ethylene primary fractiona...
# 7   84906822427  Effects of packing parameters on hydrodynamic ...
# 8   84930255037  Particle swarm optimization technique for the ...
# 9   84880698260     Experimental hydrodynamic study of valve trays
# 10  77957813896  Distillation troubleshooting by Gamma scanning...
# 11  49449086915                                Small but efficient
# 12  30844444130  Effect of increasing the load in the Amuay Ref...
# 13   1942496497  Designing sieve-tray columns. Part 2: column d...
# 14  85004262852          Hydraulic Performances of Turbogrid Trays
# 15  84944908463             Hydraulic Performances of Ripple Trays
#
#                                      publication_name      issn  \
# 0                 Computer Aided Chemical Engineering  15707946
# 1   Society of Petroleum Engineers - SPE Conferenc...      None
# 2   Chemical Engineering and Processing - Process ...  02552701
# 3                 Computer Aided Chemical Engineering  15707946
# 4                                          Nukleonika  00295922
# 5   Chemical Engineering and Processing: Process I...  02552701
# 6     AIChE Ethylene Producers Conference Proceedings      None
# 7            Xiandai Huagong/Modern Chemical Industry  02534320
# 8   Applications of Metaheuristics in Process Engi...      None
# 9                        Chemical Engineering Science  00092509
# 10           Xiandai Huagong/Modern Chemical Industry  02534320
# 11                                  Chemical Engineer  03020797
# 12  Revista Tecnica de la Facultad de Ingenieria U...  02540770
# 13                               Chemical Engineering      None
# 14                            KAGAKU KOGAKU RONBUNSHU  0386216X
# 15                            KAGAKU KOGAKU RONBUNSHU  0386216X
#
#                                                  isbn     eissn  \
# 0                                                None      None
# 1          [{'@_fa': 'true', '$': '[9781613997062]'}]      None
# 2                                                None      None
# 3                                                None      None
# 4                                                None  15085791
# 5                                                None      None
# 6          [{'@_fa': 'true', '$': '[9781510806924]'}]      None
# 7                                                None      None
# 8   [{'@_fa': 'true', '$': '[9783319065083, 331906...      None
# 9                                                None      None
# 10                                               None      None
# 11                                               None      None
# 12                                               None      None
# 13                                               None      None
# 14                                               None  13499203
# 15                                               None  13499203
#
#            volume page_range  cover_date                                 doi  \
# 0              52  1873-1878  2023-01-01  10.1016/B978-0-443-15274-0.50297-3
# 1            None       None  2022-01-01                   10.2118/200058-MS
# 2             166       None  2021-09-01           10.1016/j.cep.2021.108482
# 3              40    103-108  2017-10-01  10.1016/B978-0-444-63965-3.50019-2
# 4              62    285-287  2017-01-01              10.1515/nuka-2017-0041
# 5              97      55-65  2015-11-01           10.1016/j.cep.2015.09.002
# 6    2015-January    301-312  2015-01-01                                None
# 7              34    140-144  2014-08-20                                None
# 8   9783319065083    153-182  2014-04-01         10.1007/978-3-319-06508-3_6
# 9             100      23-32  2013-01-01           10.1016/j.ces.2013.03.030
# 10             30        4-7  2010-05-01                                None
# 11           None      42-43  2008-08-01                                None
# 12             19    189-198  1996-12-01                                None
# 13             96       None  1989-01-01                                None
# 14              3    569-574  1977-01-01         10.1252/kakoronbunshu.3.569
# 15              2    589-594  1976-01-01         10.1252/kakoronbunshu.2.589
#
#     citation_count                                        affiliation  \
# 0                0  [{'name': 'SOCAR Turkey', 'city': 'Istanbul', ...
# 1                0   [{'name': 'PDO', 'city': None, 'country': None}]
# 2                8  [{'name': 'Universidad Autónoma de Querétaro',...
# 3                0  [{'name': 'Universidad de Guanajuato', 'city':...
# 4                3  [{'name': 'Philippine Nuclear Research Institu...
# 5               17  [{'name': 'Universidad Tecnológica del Suroest...
# 6                0                                               None
# 7                1  [{'name': 'Zhejiang University of Technology',...
# 8                6  [{'name': 'Scientific Design Co.', 'city': 'Li...
# 9               21  [{'name': 'IFP Energies nouvelles', 'city': 'R...
# 10               0  [{'name': 'Bayer Technology and Engineering (S...
# 11               0  [{'name': 'Nederlandse Organisatie voor toegep...
# 12               0  [{'name': 'Grupo de Ingeniería de Procesos', '...
# 13               9                                               None
# 14               2  [{'name': 'Okayama University', 'city': 'Okaya...
# 15               3  [{'name': 'Okayama University', 'city': 'Okaya...
#
#          aggregation_type subtype_description authors  \
# 0             Book Series        Book Chapter      []
# 1   Conference Proceeding    Conference Paper      []
# 2                 Journal             Article      []
# 3             Book Series        Book Chapter      []
# 4                 Journal             Article      []
# 5                 Journal             Article      []
# 6   Conference Proceeding    Conference Paper      []
# 7                 Journal             Article      []
# 8                    Book        Book Chapter      []
# 9                 Journal             Article      []
# 10                Journal             Article      []
# 11          Trade Journal             Article      []
# 12                Journal             Article      []
# 13                Journal             Article      []
# 14                Journal             Article      []
# 15                Journal             Article      []
#
#                                             full_text  year
# 0   https://api.elsevier.com/content/article/eid/1...  2023
# 1                                                None  2022
# 2   https://api.elsevier.com/content/article/eid/1...  2021
# 3   https://api.elsevier.com/content/article/eid/1...  2017
# 4                                                None  2017
# 5   https://api.elsevier.com/content/article/eid/1...  2015
# 6                                                None  2015
# 7                                                None  2014
# 8                                                None  2014
# 9   https://api.elsevier.com/content/article/eid/1...  2013
# 10                                               None  2010
# 11                                               None  2008
# 12                                               None  1996
# 13                                               None  1989
# 14                                               None  1977
# 15                                               None  1976

# %% [markdown]
# # Visualizar la matriz de datos faltantes

# %%
print("\nMatriz de Datos Faltantes:")
msno.matrix(df)
plt.show()
# Out:
# Matriz de Datos Faltantes:

# %% [markdown]
# # Visualizar el mapa de calor de datos faltantes

# %%
print("\nMapa de Calor de Datos Faltantes:")
msno.heatmap(df)
plt.show()
# Out:
# Mapa de Calor de Datos Faltantes:

# %% [markdown]
# # Visualizar la gráfica de barras para contar los datos faltantes

# %%
print("\nGráfico de Barras de Datos Faltantes:")
msno.bar(df)
plt.show()
# Out:
# Gráfico de Barras de Datos Faltantes:
